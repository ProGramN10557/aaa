# %%
import pandas as pd
import numpy as np

df1=pd.read_csv('Default.csv')
print(df1)

import pandas as pd
import numpy as np

df1=pd.read_csv('acme.csv')
print(df1)

shape = df1.shape
print(shape)

description = df1.describe()
print(description)

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
sns.heatmap(df1.corr(), square=True,annot=True)
# Out:
#      default student      balance        incomeeeee
# 0         No      No   729.526495  44361.625070
# 1         No     Yes   817.180407  12106.134700
# 2         No      No  1073.549164  31767.138950
# 3         No      No   529.250605  35704.493940
# 4         No      No   785.655883  38463.495880
# 5         No     Yes   919.588530   7491.558572
# 6         No      No   825.513330  24905.226580
# 7         No     Yes   808.667504  17600.451340
# 8         No      No  1161.057854  37468.529290
# 9         No      No     0.000000  29275.268290
# 10        No     Yes     0.000000  21871.073090
# 11        No     Yes  1220.583753  13268.562220
# 12        No      No   237.045114  28251.695340
# 13        No      No   606.742343  44994.555850
# 14        No      No  1112.968401  23810.174050
# 15        No      No   286.232560  45042.413040
# 16        No      No     0.000000  50265.312350
# 17        No     Yes   527.540184  17636.539620
# ...
